# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\youssef azam\Desktop\finle project\Project for python\loan_data.csv")
data.head(2)
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# 0            0        0               0
# 1            0        0               0

# %%
data.shape
# Out:
# (9578, 14)

# %%
data.isnull().sum()
# Out:
# credit.policy        0
# purpose              0
# int.rate             0
# installment          0
# log.annual.inc       0
# dti                  0
# fico                 0
# days.with.cr.line    0
# revol.bal            0
# revol.util           0
# inq.last.6mths       0
# delinq.2yrs          0
# pub.rec              0
# not.fully.paid       0
# dtype: int64

# %%
data.head
# Out:
# <bound method NDFrame.head of       credit.policy             purpose  int.rate  installment  \
# 0                 1  debt_consolidation    0.1189       829.10
# 1                 1         credit_card    0.1071       228.22
# 2                 1  debt_consolidation    0.1357       366.86
# 3                 1  debt_consolidation    0.1008       162.34
# 4                 1         credit_card    0.1426       102.92
# ...             ...                 ...       ...          ...
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 0          11.350407  19.48   737        5639.958333      28854        52.1
# ...

# %%
data.columns
# Out:
# Index(['credit.policy', 'purpose', 'int.rate', 'installment', 'log.annual.inc',
#        'dti', 'fico', 'days.with.cr.line', 'revol.bal', 'revol.util',
#        'inq.last.6mths', 'delinq.2yrs', 'pub.rec', 'not.fully.paid'],
#       dtype='object')

# %%
data.describe().round()
# Out:
#        credit.policy  int.rate  installment  log.annual.inc     dti    fico  \
# count         9578.0    9578.0       9578.0          9578.0  9578.0  9578.0
# mean             1.0       0.0        319.0            11.0    13.0   711.0
# std              0.0       0.0        207.0             1.0     7.0    38.0
# min              0.0       0.0         16.0             8.0     0.0   612.0
# 25%              1.0       0.0        164.0            11.0     7.0   682.0
# 50%              1.0       0.0        269.0            11.0    13.0   707.0
# 75%              1.0       0.0        433.0            11.0    18.0   737.0
# max              1.0       0.0        940.0            15.0    30.0   827.0
#
#        days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# count             9578.0     9578.0      9578.0          9578.0       9578.0
# mean              4561.0    16914.0        47.0             2.0          0.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
round(data['revol.bal'].describe())
# Out:
# count       9578.0
# mean       16914.0
# std        33756.0
# min            0.0
# 25%         3187.0
# 50%         8596.0
# 75%        18250.0
# max      1207359.0
# Name: revol.bal, dtype: float64

# %%
round(data['revol.util'].describe())
# Out:
# count    9578.0
# mean       47.0
# std        29.0
# min         0.0
# 25%        23.0
# 50%        46.0
# 75%        71.0
# max       119.0
# Name: revol.util, dtype: float64

# %%
round(data['fico'].describe())
# Out:
# count    9578.0
# mean      711.0
# std        38.0
# min       612.0
# 25%       682.0
# 50%       707.0
# 75%       737.0
# max       827.0
# Name: fico, dtype: float64

# %%
round(data['days.with.cr.line'].describe())
# Out:
# count     9578.0
# mean      4561.0
# std       2497.0
# min        179.0
# 25%       2820.0
# 50%       4140.0
# 75%       5730.0
# max      17640.0
# Name: days.with.cr.line, dtype: float64

# %%
data["purpose"].value_counts()
# Out:
# debt_consolidation    3957
# all_other             2331
# credit_card           1262
# home_improvement       629
# small_business         619
# major_purchase         437
# educational            343
# Name: purpose, dtype: int64

# %%
data["credit.policy"].value_counts()
# Out:
# 1    7710
# 0    1868
# Name: credit.policy, dtype: int64

# %%
data["inq.last.6mths"].value_counts()
# Out:
# 0     3637
# 1     2462
# 2     1384
# 3      864
# 4      475
# 5      278
# 6      165
# 7      100
# 8       72
# 9       47
# 10      23
# 11      15
# 12      15
# 15       9
# 13       6
# 14       6
# 18       4
# 16       3
# 19       2
# 24       2
# 17       2
# 33       1
# 20       1
# 27       1
# 25       1
# 28       1
# 31       1
# 32       1
# Name: inq.last.6mths, dtype: int64

# %%
data["delinq.2yrs"].value_counts()
# Out:
# 0     8458
# 1      832
# 2      192
# 3       65
# 4       19
# 5        6
# 6        2
# 13       1
# 7        1
# 8        1
# 11       1
# Name: delinq.2yrs, dtype: int64

# %%
data["pub.rec"].value_counts()
# Out:
# 0    9019
# 1     533
# 2      19
# 3       5
# 4       1
# 5       1
# Name: pub.rec, dtype: int64

# %%
data["not.fully.paid"].value_counts()
# Out:
# 0    8045
# 1    1533
# Name: not.fully.paid, dtype: int64

# %%
data.groupby('purpose')['int.rate'].aggregate(['min','max','mean'])
# Out:
#                        min     max      mean
# purpose
# all_other           0.0639  0.2164  0.116771
# credit_card         0.0600  0.2086  0.119738
# debt_consolidation  0.0600  0.2121  0.126595
# educational         0.0600  0.2011  0.119907
# home_improvement    0.0600  0.2164  0.117507
# major_purchase      0.0705  0.2017  0.114171
# small_business      0.0714  0.2121  0.138087

# %%
data.hist(figsize=(20,20),color='#1c9093')
plt.show()

# %%
sns.relplot(y='installment',x='days.with.cr.line',hue='not.fully.paid',data=data)

# %%
sns.countplot(x=data['not.fully.paid'],color='#200431')
# Out:
# <AxesSubplot:xlabel='not.fully.paid', ylabel='count'>

# %%
sns.countplot(x=data['credit.policy'],color='#1c9099')
# Out:
# <AxesSubplot:xlabel='credit.policy', ylabel='count'>

# %%
sns.countplot(x=data['inq.last.6mths'],color='#a8ddb5')
# Out:
# <AxesSubplot:xlabel='inq.last.6mths', ylabel='count'>

# %%
sns.countplot(x=data['pub.rec'],color='#a8dcf5')
# Out:
# <AxesSubplot:xlabel='pub.rec', ylabel='count'>

# %%
sns.boxplot(data=data['fico'])
# Out:
# <AxesSubplot:>

# %%
data.head(2)
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# 0            0        0               0
# 1            0        0               0

# %%
y=data['credit.policy']
plt.pie(y)
plt.show()
